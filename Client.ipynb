# %%
import matplotlib.pyplot as plt
# !pip install netgraph
from netgraph import Graph

def Client(Core):
  labels = {0:Core,1:'SUPPORT ACTIVITIES\nManagement\nHRM\nFinance\nAccounting'}
  colors = {0:'grey',1:'gold'}
  shapes = {0:'o',1:'o'}
  client = [(1,0)]
  fig = plt.figure(figsize=(5,5))
  Graph(client,node_size=30,node_labels=labels,node_color=colors,node_shape=shapes,node_edge_width=2,edge_width=2,arrows=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: netgraph in /usr/local/lib/python3.7/dist-packages (4.9.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from netgraph) (3.2.2)
# Requirement already satisfied: grandalf in /usr/local/lib/python3.7/dist-packages (from netgraph) (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from netgraph) (1.21.6)
# Requirement already satisfied: rectangle-packer in /usr/local/lib/python3.7/dist-packages (from netgraph) (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from netgraph) (1.7.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from grandalf->netgraph) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->netgraph) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->netgraph) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->netgraph) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->netgraph) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->netgraph) (1.15.0)
